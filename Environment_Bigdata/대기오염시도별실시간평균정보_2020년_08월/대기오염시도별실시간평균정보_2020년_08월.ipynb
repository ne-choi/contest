# %% [markdown]
# # **대기오염시도별실시간평균정보_2020년_08월**

# %%
import pandas as pd

df_sn = pd.read_csv("대기오염시도별실시간평균정보_2020년_08월.csv")
df_sn.columns = ["기간","측정항목","데이터 구분","서울","부산","대구","인천","광주","울산","대전","경기","강원","충북","충남","전북","전남","경북","경남","제주","세종"]
df_sn
# Out:
#              기간   측정항목 데이터 구분      서울      부산      대구      인천      광주      울산  \
# 0    2020-09-24    SO2    일평균   0.002   0.003   0.002   0.003   0.003   0.003
# 1    2020-09-23    SO2    일평균   0.002   0.004   0.002   0.003   0.003   0.002
# 2    2020-09-22    SO2    일평균   0.002   0.004   0.002   0.003   0.003   0.002
# 3    2020-09-21    SO2    일평균   0.003   0.005   0.002   0.004   0.003   0.002
# 4    2020-09-20    SO2    일평균   0.003   0.003   0.002   0.004   0.003   0.002
# ..          ...    ...    ...     ...     ...     ...     ...     ...     ...
# 175  2020-08-30  PM2.5    일평균   9.000  14.000  11.000  10.000   6.000   3.000
# 176  2020-08-29  PM2.5    일평균  10.000   7.000   8.000  10.000   4.000   3.000
# 177  2020-08-28  PM2.5    일평균  15.000   6.000  11.000  12.000   7.000   8.000
# 178  2020-08-27  PM2.5    일평균  12.000   8.000  11.000  12.000  14.000  12.000
# 179  2020-08-26  PM2.5    일평균  16.000  10.000  16.000  15.000   9.000  12.000
#
# ...

# %%
df_sn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   기간      180 non-null    object
#  1   측정항목    180 non-null    object
#  2   데이터 구분  180 non-null    object
#  3   서울      180 non-null    float64
#  4   부산      180 non-null    float64
#  5   대구      180 non-null    float64
#  6   인천      180 non-null    float64
#  7   광주      180 non-null    float64
#  8   울산      180 non-null    float64
#  9   대전      180 non-null    float64
#  10  경기      180 non-null    float64
#  11  강원      180 non-null    float64
#  12  충북      180 non-null    float64
#  13  충남      180 non-null    float64
#  14  전북      180 non-null    float64
#  15  전남      180 non-null    float64
#  16  경북      180 non-null    float64
#  17  경남      180 non-null    float64
#  18  제주      172 non-null    float64
#  19  세종      180 non-null    float64
# dtypes: float64(17), object(3)
# ...

# %%
df_sn = df_sn.sort_values(['기간'])
df_sn
# Out:
#              기간   측정항목 데이터 구분      서울      부산      대구      인천      광주      울산  \
# 89   2020-08-26     O3    일평균   0.023   0.027   0.023   0.025   0.029   0.027
# 150  2020-08-26   PM10    일평균  23.000  28.000  26.000  25.000  16.000  22.000
# 120  2020-08-26    NO2    일평균   0.013   0.008   0.008   0.013   0.004   0.009
# 59   2020-08-26     CO    일평균   0.300   0.300   0.300   0.300   0.300   0.200
# 29   2020-08-26    SO2    일평균   0.003   0.003   0.003   0.003   0.004   0.002
# ..          ...    ...    ...     ...     ...     ...     ...     ...     ...
# 90   2020-09-24    NO2    일평균   0.009   0.009   0.013   0.012   0.012   0.011
# 121  2020-09-24   PM10    일평균   9.000  20.000  18.000   9.000  15.000  12.000
# 151  2020-09-24  PM2.5    일평균   3.000   7.000   7.000   3.000   8.000   5.000
# 60   2020-09-24     O3    일평균   0.027   0.034   0.023   0.027   0.023   0.028
# 0    2020-09-24    SO2    일평균   0.002   0.003   0.002   0.003   0.003   0.003
#
# ...

# %%
df_sn = df_sn.drop(["데이터 구분","부산","대구","광주","울산","대전","강원","충북","충남","전북","전남","경북","경남","제주","세종"], axis = 1)

# %%
df_sn
# Out:
#              기간   측정항목      서울      인천      경기
# 89   2020-08-26     O3   0.023   0.025   0.026
# 150  2020-08-26   PM10  23.000  25.000  25.000
# 120  2020-08-26    NO2   0.013   0.013   0.010
# 59   2020-08-26     CO   0.300   0.300   0.300
# 29   2020-08-26    SO2   0.003   0.003   0.003
# ..          ...    ...     ...     ...     ...
# 90   2020-09-24    NO2   0.009   0.012   0.008
# 121  2020-09-24   PM10   9.000   9.000  11.000
# 151  2020-09-24  PM2.5   3.000   3.000   3.000
# 60   2020-09-24     O3   0.027   0.027   0.029
# 0    2020-09-24    SO2   0.002   0.003   0.003
#
# [180 rows x 5 columns]

# %%
index = ['SO2','SO2','SO2','NO2','NO2','NO2','PM10','PM10','PM10','PM2.5','PM2.5','PM2.5']

# %%
df_sn = df_sn.sort_values(['기간'])
df_sn
# Out:
#                기간    서울    인천    경기
# 측정항목
# PM10   2020-09-22  14.0  18.0  18.0
# PM2.5  2020-09-22   7.0   9.0   9.0
# PM10   2020-09-23   8.0   9.0  10.0
# PM2.5  2020-09-23   3.0   3.0   3.0
# PM10   2020-09-24   9.0   9.0  11.0
# PM2.5  2020-09-24   3.0   3.0   3.0

# %%
df_sn["서울"].unique()
# Out:
# array([14.,  7.,  8.,  3.,  9.])

# %%
df_sn["서울"].value_counts()
# Out:
# 3.0     2
# 9.0     1
# 8.0     1
# 7.0     1
# 14.0    1
# Name: 서울, dtype: int64

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 시각화 사전 준비
sns.set_context("talk")
sns.set_style("white")

# 한글 사용 준비
plt.rcParams['font.family']='NanumGothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
fig, ax = plt.subplots(figsize=(20, 9))
 
ax = df_sn[["서울", "경기","인천"]].plot.bar(ax=ax)

# x = pd.date_range('2020-09-22', '2020-09-24')
# plt.plot(x, np.arange(len(x)))
plt.xticks(rotation=0)

#plt.xticks(range(0,max(ax),5))    # x축의 눈금의 범위 : 눈금의 범위 + 눈금의 간격
#plt.plot(x,y)

# 주변 테두리를 제거
ax.spines["left"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)

ax.grid(axis="y")

ax.set_title("경기도권 3일")



# 범례 추가
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 9))
 
ax = df_sn[["서울", "경기","인천"]].plot.bar(ax=ax)

# x = pd.date_range('2020-09-22', '2020-09-24')
# plt.plot(x, np.arange(len(x)))
plt.xticks(rotation=0)

#plt.xticks(range(0,max(ax),5))    # x축의 눈금의 범위 : 눈금의 범위 + 눈금의 간격
#plt.plot(x,y)

# 주변 테두리를 제거
ax.spines["left"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)

ax.grid(axis="y")



title_font = {
    'fontsize': 16,
    'fontweight': 'bold'
}
plt.title('경기도권 24시간 기준 3일 측정', fontdict=title_font, loc='center', pad=40)

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width()/2.,
            height+ 0.5, height, ha='center', size=15)

plt.ylabel('㎍/m³',fontsize = 23)

    
# 범례 추가
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 9))
 
ax = df_sn[["서울", "경기","인천"]].plot.bar(ax=ax)

# x = pd.date_range('2020-09-22', '2020-09-24')
# plt.plot(x, np.arange(len(x)))
plt.xticks(rotation=0)

#plt.xticks(range(0,max(ax),5))    # x축의 눈금의 범위 : 눈금의 범위 + 눈금의 간격
#plt.plot(x,y)

# 주변 테두리를 제거
ax.spines["left"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)

ax.grid(axis="y")

ax.set_title("경기도권 3일")

text(측정항목,'HorizontalAlignment','center',
    'VerticalAlignment','bottom')

# 범례 추가
ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-119-ac8a0ef1d5bf> in <module>
#      19 ax.set_title("경기도권 3일")
#      20
# ---> 21 text(측정항목,'HorizontalAlignment','center',
#      22     'VerticalAlignment','bottom')
#      23
#
# NameError: name 'text' is not defined

# %%
fig, ax = plt.subplots(figsize=(20, 9))
ax.plot(df_sn.loc[121:123, "기간"], df_sn.loc[121:123,"서울"],'o-', label = '서울')
ax.plot(df_sn.loc[121:123, "기간"], df_sn.loc[121:123,"경기"],'o:', label = '경기')
ax.plot(df_sn.loc[121:123, "기간"], df_sn.loc[121:123,"인천"],'o--', label = '인천')


plt.axhline(y=10, color='r', linewidth=3)

# 주변 테두리를 제거
ax.spines["left"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)

ax.grid(axis="y")



ax.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(20, 9))

x = np.arange(3)
time = ['2020-09-24', '2020-09-23', '2020-09-22']
values = [3, 3, 3]

plt.bar(x, values)
plt.xticks(x, time)
plt.show()

# %%
fig = plt.figure(figsize=(12,7))

widths = [4, 4]
heights = [1, 4]

# widths 와 행,열 수가 맞아야한다

### 1. gridspec preparation
spec = fig.add_gridspec(ncols=2, nrows=2, width_ratios=widths, height_ratios=heights)

### 2. setting axes
axs = {}
for i in range(len(heights)*len(widths)):
    axs[i] = fig.add_subplot(spec[i//len(widths), i%len(widths)])
    axs[i].text(0.5, 0.5, f"axs[{i}]", fontdict={"horizontalalignment":"center", "color":"gray"})

# %%
fig = plt.figure(figsize=(12,7))

widths = [4, 4]
heights = [1, 4]

# 1. gridspec preparation
spec = fig.add_gridspec(ncols=2, nrows=2, width_ratios=widths, height_ratios=heights)

# 2. setting axes
axs = {}
for i in range(len(heights)*len(widths)):
    axs[i] = fig.add_subplot(spec[i//len(widths), i%len(widths)])
    
# 4. scatterplot - seoul vs gyeonggi
sns.scatterplot("서울","경기", data = df_sn,hue ="측정항목", ax = axs[2])

# histogram
sns.kdeplot(y="서울", data = df_sn, hue = "측정항목", ax = axs[0],legend=False)
axs[0].set_xlim(axs[3].get_xlim())
axs[0].set_xlabel('')
axs[0].set_xticklabels([])
axs[0].spines["left"].set_visible(False)
axs[0].spines["top"].set_visible(False)
axs[0].spines["right"].set_visible(False)

# scatterplot - seoul vs incheon
sns.scatterplot("서울","인천", data = df_sn, hue="측정항목", ax = axs[3])

sns.kdeplot("인천", data=df_sn, hue="측정항목", ax=axs[1], legend=False)
axs[1].set_xlim(axs[3].get_xlim())
axs[1].set_xlabel('')
axs[1].set_xticklabels([])
axs[1].spines["left"].set_visible(False)
axs[1].spines["top"].set_visible(False)

axs[1].spines["right"].set_visible(False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ...

# %%
fig, ax = plt.subplots(figsize=(20, 9))
 
ax = df_sn[["서울", "경기","인천"]].plot.bar(ax=ax)

# x = pd.date_range('2020-09-22', '2020-09-24')
# plt.plot(x, np.arange(len(x)))
plt.xticks(rotation=0)

#plt.xticks(range(0,max(ax),5))    # x축의 눈금의 범위 : 눈금의 범위 + 눈금의 간격
#plt.plot(x,y)

# 주변 테두리를 제거
ax.spines["left"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)

ax.grid(axis="y")



title_font = {
    'fontsize': 16,
    'fontweight': 'bold'
}
plt.title('경기도권 24시간 기준 3일 측정', fontdict=title_font, loc='center', pad=40)

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width()/2.,
            height+ 0.5, height, ha='center', size=15)

plt.ylabel('㎍/m³',fontsize = 23)
plt.xlabel('측정항목')


plt.text(1.2, 14, '2020-09-22',fontweight = "bold")
plt.text(3.2, 14, '2020-09-23',fontweight = "bold")
plt.text(5, 14, '2020-09-24',fontweight = "bold")
plt.axvline(x=1.5, ymin=0.005, ymax=0.7, color = 'r')
plt.axvline(x=3.5, ymin=0.005, ymax=0.7, color = 'r')
plt.axvline(x=5.4, ymin=0.005, ymax=0.7, color = 'r')


# 범례 추가
ax.legend()
plt.show()
